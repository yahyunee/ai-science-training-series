# %% [markdown]
# # Artificial intelligence in a nutshell
#
# In this notebook, we will talk about
# * What is AI training?
# * How does large language model work?
# * A simple AI model: linear regression
#
# **How to run this notebook on Polaris**
# * Go to https://jupyter.alcf.anl.gov, and click "Login Polaris"
# * After login, select ```ALCFAITP``` project and ```ALCFAITP``` queue during the lecture (use ```debug``` queue outside of the lecture)
# * Load the notebook and select "datascience/conda-2023-01-10" python kernel
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/jupyter1.png?raw=1" width="600" />
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/jupyter2.png?raw=1" width="600" />
# </p>
#
# **How to run this notebook on Google Colab**
#
# * Go to https://colab.research.google.com/, sign in or sign up
# * "File"-> "open notebook"
# * choose ```01_intro_AI_on_Supercomputer/01_linear_regression_sgd.ipynb``` from the list
# ![Google Colab](https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/colab.png?raw=1)
#
# ## What is AI training?
# **Two ways of learning English**
# * through learning rules;
# * through hearing a lot of speakings
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/data_driven.png?raw=1" width="1000" />
# </p>
#
# I learned English in my middle school, and memorized a lot of grammar rules in my mind. Every time when I speak, I try to follow the grammar rules as much as I can. But I always break the rules.
#
# However, my daugher learned English differently. She learns speaking by hearing a lot of speaking from TV, teachers, classmates, and her older brother. The fact is that, she seldomly breaks grammar rules. This way of learning by observing patterns is very powerful! This is the essence of AI or data driven science.
#
# ## How does large language model work?
#
# Large Language Models, like GPT, function by pre-training on extensive datasets to learn language patterns, utilizing transformer architecture for contextual understanding, and can be fine-tuned for specific tasks, enabling them to generate coherent and contextually relevant text based on provided inputs.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/llm2.png?raw=1" width="600" />
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/chatgpt_response.png?raw=1" width="160" />
# </p>
#
# **More complicated example**
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/chatgpt_poem.png?raw=1" width="400" />
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/martin.png?raw=1" width="450" />
# </p>
#
# You can do this on https://chat.openai.com
#
# ## Simplest AI model example: linear regression
# This example is adopted from Bethany Lusch, ALCF.
#
# Linear regression is the simplest example ``learning" from existing data for future prediction.
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/excel_linear_regression.jpg?raw=1" width="400" />
# </p>
#
# We're going to review the math involved in this process to help understand how training an AI works.
#
# First we will load some tools that others wrote and we can use to help us work.
# * [Pandas](https://pandas.pydata.org/docs/): a toolkit for working with row vs. column data, like excel sheets, and CSV (Comma Seperated Values) files.
# * [Numpy](https://numpy.org/doc/): a toolkit for managing arrays, vectors, matrices, etc, doing math with them, slicing them up, and many other handy things.
# * [Matplotlib](https://matplotlib.org/stable/index.html): a toolkit for plotting data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipydis
import time

# %% [markdown]
# ### Dataset
# We used a realestate dataset from Kaggle to produce this reduced dataset. This dataset contains the _sale price_ and _above ground square feet_ of many houses. We can use this data for our linear regression.
#
# We use Pandas to read the data file which is stored as Comma Separated Values (CSV). and print the column labels. CSV files are similar to excel sheets.

# %%
! [ -e ./slimmed_realestate_data.csv ] || wget https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
data = pd.read_csv('slimmed_realestate_data.csv')
print(data.columns)
# Out:
# --2024-11-08 14:32:38--  https://raw.githubusercontent.com/argonne-lcf/ai-science-training-series/main/01_intro_AI_on_Supercomputer/slimmed_realestate_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8804 (8.6K) [text/plain]
# Saving to: ‘slimmed_realestate_data.csv’
#
# slimmed_realestate_ 100%[===================>]   8.60K  --.-KB/s    in 0s
#
# 2024-11-08 14:32:38 (36.2 MB/s) - ‘slimmed_realestate_data.csv’ saved [8804/8804]
#
# Index(['Unnamed: 0', 'SalePrice', 'GrLivArea'], dtype='object')

# %% [markdown]
# Now pandas provides some helpful tools for us to inspect our data. It provides a `plot()` function that, behind the scenes, is calling into the _Matplotlib_ library and calling the function [matplotlib.pyplot.plot()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html). In this case, we simply tell it the names of the columns we want as our _x_ and _y_ values and the `style` (`'.'` tells `matplotlib` to use a small dot to represent each data point).

# %%
data.plot(x='GrLivArea', y='SalePrice',style='.')
# Out:
# <Axes: xlabel='GrLivArea'>

# %% [markdown]
# ### Theory of linear regression
#
# The goal of learning regression is to find a line that is closest to all the points.
#
# The slope and intercept of such a line $y = m x + b$ can be found as:
#
# $$m = { n (\Sigma xy) - (\Sigma x) (\Sigma y) \over n (\Sigma x^2) - (\Sigma x)^2 } $$
#
# $$b = { (\Sigma y) (\Sigma x^2) - (\Sigma x) (\Sigma xy) \over n (\Sigma x^2) - (\Sigma x)^2 } $$
#
# Details derivation of this can be found [here](https://en.wikipedia.org/wiki/Simple_linear_regression).
#
# We'll break this calculation into a few steps to help make it easier.
#
# First lets define $x$ and $y$. $x$ will be our _above ground square footage_ and $y$ will be _sale price_. In our equations we have a few different values we need, such as $n$ which is just the number of points we have:

# %%
n = len(data)

# %% [markdown]
# Then we need our $x$ and $y$ by selecting only the column we care about for each one. Note about data formats: `data` is a Pandas [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html#pandas.DataFrame) object which has rows and columns; `data['GrLivArea']` is a Pandas [Series](https://pandas.pydata.org/docs/reference/api/pandas.Series.html) object which only has rows; then we also convert from _Pandas_ data formats (in this case a _Series_) to _Numpy_ data formats using the `to_numpy()` function which is part of the Pandas _Series_ object.

# %%
x = data['GrLivArea'].to_numpy()
y = data['SalePrice'].to_numpy()

# %% [markdown]
# Now we will calculate $\Sigma xy$, $\Sigma x$, $\Sigma y$, and $\Sigma x^2$:

# %%
sum_xy = np.sum(x*y)
sum_x = np.sum(x)
sum_y = np.sum(y)
sum_x2 = np.sum(x*x)

# %% [markdown]
# The denominator in the equation for $m$ and $b$ are the same so we can calculate that once:

# %%
denominator = n * sum_x2 - sum_x * sum_x

# %% [markdown]
# Then we can calculate our fit values:

# %%
m = (n * sum_xy - sum_x * sum_y) / denominator
b = (sum_y * sum_x2 - sum_x * sum_xy) / denominator
print('y = %f * x + %f' % (m,b))

# saving these for later comparison
m_calc = m
b_calc = b
# Out:
# y = 87.688145 * x + 34754.077892

# %% [markdown]
# Now we can plot the fit results with our data to see how we did.
#
# First we define a plotting function because we're going to do this often and we want to reuse our code:

# %%
def plot_data(x,y,m,b,plt = plt):
   # plot our data points with 'bo' = blue circles
   plt.plot(x,y,'bo')
   # create the line based on our linear fit
   # first we need to make x points
   # the 'arange' function generates points between two limits (min,max)
   linear_x = np.arange(x.min(),x.max())
   # now we use our fit parameters to calculate the y points based on our x points
   linear_y = linear_x * m + b
   # plot the linear points using 'r-' = red line
   plt.plot(linear_x,linear_y,'r-',label='fit')

# %% [markdown]
# Now can use this function to plot our results:

# %%
plot_data(x,y,m,b)

# %% [markdown]
# ### Training through Stochastic Gradient Descent (SGD)
#
# SGD is a common method in AI for training deep neural networks on large datasets. It is an iterative method for optimizing a loss function that we get to define. We will use this simple linear regression to demonstrate how it works.
#
# #### The model
#
# In AI, neural networks are often referred to as a _model_ because, once fully trained, they should model (AKA predict) the behavior of our system. In our example, the system is how house prices vary based on house size. We know our system is roughly driven by a linear function:
#
# $$ \hat{y_i}(x_i) = m * x_i + b $$
#
# We just need to figure out $m$ and $b$. Let's create a function that calculates our model given $x$, $m$, and $b$.

# %%
def model(x,m,b):
   return m * x + b

# %% [markdown]
# #### The Loss Function
#
# A _loss function_, or _objective function_, is something we define and is based on what we want to achieve. In the method of SGD, it is our goal to minimize (or make close to zero) the values calculated from the _loss function_. In our example, we ideally want the prediction of our _model_ to be equal to the actual data, though we will settle for "as close as possible".
#
# So we will select our _loss function_ to be the [Mean Squared Error](https://en.wikipedia.org/wiki/Mean_squared_error) function:
#
# $$ L(y_i,\hat{y_i}) = (y_i - \hat{y_i}(x_i))^2 $$
#
# where $y_i$ is our $i^{th}$ entry in the `data['SalePrice']` vector and $\hat{y_i}$ is the prediction based on evaluting $m * x_i + b$.
#
# This function looks like the figure below when we plot it with $x=y_i - \hat{y_i}(x_i)$ and we we want to be down near $y_i - \hat{y_i}(x_i) = 0$ which indicates that our $y_i$ is as close as possible to $\hat{y_i}$.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/loss_func.png?raw=1" width="400" />
# </p>
#
# Here we crate a function that calculates this for us.

# %%
def loss(x,y,m,b):
   y_predicted = model(x,m,b)
   return np.power( y - y_predicted, 2 )

# %% [markdown]
# #### Minimizing the Loss Function
#
# We want to use the loss function in order to guide how to update $m$ and $b$ to better model our system. In calculus we learn to minimize a function with respect to a variable you calculate the _partial derivative_ with respect to the variable you want to vary.
#
# $$ { \partial L \over \partial m } = 0 $$
#
# The location of the solution to this is the minimum as shown in the figure above. We can write down the partial derivative of the loss function as:
#
# $$ { \partial L \over \partial m } = -2 x_i (y_i - \hat{y_i}(x_i)) $$
# $$ { \partial L \over \partial b } = -2 (y_i - \hat{y_i}(x_i)) $$
#
# We can use this to calculate an adjustment to $m$ and $b$ that will reduce the loss function, effectively improving our fitting parameters. This is done using this equation:
#
# $$ m' = m - \eta { \partial L \over \partial m }$$
# $$ b' = b - \eta { \partial L \over \partial b }$$
#
# Here our original $m$ and $b$ are adjusted by the partial derivative multiplied by some small factor, $\eta$, called the _learning rate_. This learning rate is very important in our process and must be tuned for every problem.
#
# In our example, the selection of the learning rate essentially defines how close we can get to the minimum, AKA the best fit solution. This figure shows what happens when we pick a large learning rate. We first select a starting point in our loss function (typically randomly), then every update from $m$/$b$ to $m'$/$b'$ results in a shift to somewhere else on our loss function (following the red arrows). In this example, our learning rate ($\eta$) has been selected too large such that we bounce back and forth around the minimum, never reaching it.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/parabola_largeLR.png?raw=1" width="400" />
# </p>
#
# If we select a smaller learning we can see better behavior in the next figure.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/parabola_smallLR.png?raw=1" width="400" />
# </p>
#
# Though, keep in mind, too small a learning rate results is so little progress toward the minimum that you may never reach it!
#
# A pit fall of SGD that one must be aware of is when your loss function is complex, with many minima. The next figure shows such a case, in which we select a small learning rate and our starting point happens to be near a local minimum that is not the lowest minimum. As shown, we do reach a minimum, but it isn't the lowest minimum in our loss function. It could be that we randomly select a starting point near the minimum we care about, but we should build methods that are more robust against randomly getting the right answer.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_smallLR.png?raw=1" width="400" />
# </p>
#
# Then, if we increase our learning rate too much, we bounce around again.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_largeLR.png?raw=1" width="400" />
# </p>
#
# What we want to do in this situation is start with a large learning rate and slowly reduce its size as we progress. That is shown in this next figure.
#
# <p float="center">
#   <img src="https://github.com/yahyunee/ai-science-training-series/blob/main/01_intro_AI_on_Supercomputer/figures/local_min_variableLR.png?raw=1" width="400" />
# </p>
#
# As you can see, this process is not perfect and could still land in a local minimum, but it is important to be aware of these behaviors as you utilize SGD in machine learning.
#
# So let's continue, we'll build functions we can use to update our fit parameters, $m$ and $b$.

# %%
def updated_m(x,y,m,b,learning_rate):
   dL_dm = - 2 * x * (y - model(x,m,b))
   dL_dm = np.mean(dL_dm)
   return m - learning_rate * dL_dm

def updated_b(x,y,m,b,learning_rate):
   dL_db = - 2 * (y - model(x,m,b))
   dL_db = np.mean(dL_db)
   return b - learning_rate * dL_db

# %% [markdown]
# # Putting it together
#
# We can now randomly select our initial slope and intercept:

# %%
m = 5.
b = 1000.
print('y_i = %.2f * x + %.2f' % (m,b))
# Out:
# y_i = 5.00 * x + 1000.00

# %% [markdown]
# Then we can calculate our Loss function:

# %%
l = loss(x,y,m,b)
print('first 10 loss values: ',l[:10])
# Out:
# first 10 loss values:  [3.03421561e+10 3.55511025e+10 1.24579082e+10 1.91656336e+10
#  1.60604929e+10 2.04432804e+10 1.72410030e+10 1.76517796e+10
#  1.52769600e+10 2.18152900e+10]

# %%
learning_rate = 1e-9
m = updated_m(x,y,m,b,learning_rate)
b = updated_b(x,y,m,b,learning_rate)
print('y_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f' % (m,b,m_calc,b_calc))
plot_data(x,y,m,b)
# Out:
# y_i = 5.47 * x + 1000.00     previously calculated: y_i = 87.69 * x + 34754.08

# %%
# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []
# convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
data_x = data['GrLivArea'].to_numpy()
data_y = data['SalePrice'].to_numpy()
# we run our loop N times
loop_N = 30
for i in range(loop_N):
   # update our slope and intercept based on the current values
   m = updated_m(data_x,data_y,m,b,learning_rate_m)
   b = updated_b(data_x,data_y,m,b,learning_rate_b)

   # calculate the loss value
   loss_value = np.mean(loss(data_x,data_y,m,b))

   # keep a history of our loss values
   loss_history.append(loss_value)

   # print our progress
   print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))

   # close/delete previous plots
   plt.close('all')

   # create a 1 by 2 plot grid
   fig,ax = plt.subplots(1,2,figsize=(18,6),dpi=80)
   # lot our usual output
   plot_data(data_x,data_y,m,b,ax[0])

   # here we also plot the calculated linear fit for comparison
   line_x = np.arange(data_x.min(),data_x.max())
   line_y = line_x * m_calc + b_calc
   ax[0].plot(line_x,line_y,'b-',label='calculated')
   # add a legend to the plot and x/y labels
   ax[0].legend()
   ax[0].set_xlabel('square footage')
   ax[0].set_ylabel('sale price')

   # plot the loss
   loss_x = np.arange(0,len(loss_history))
   loss_y = np.asarray(loss_history)
   ax[1].plot(loss_x,loss_y, 'o-')
   ax[1].set_yscale('log')
   ax[1].set_xlabel('loop step')
   ax[1].set_ylabel('loss')
   plt.show()
   # gives us time to see the plot
   time.sleep(2.5)
   # clears the plot when the next plot is ready to show.
   ipydis.clear_output(wait=True)
# Out:
# [029]  dy_i = 88.89 * x + 32912.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1478200827.641291

# %% [markdown]
# # Homework
# ## Mini Batch Training
# In AI, datasets are often very large and cannot be processed all at once as is done in the loop above. The data is instead randomly sampled in smaller _batches_ where each _batch_ contains `batch_size` inputs. How can you change the loop above to sample the dataset in smaller batches? Hint: Our `data` variable is a Pandas `DataFrame` object, search for "how to sample a DataFrame".
#
# Instead of using the entire dataset like
# ```python
# data_x = data['GrLivArea'].to_numpy()
# data_y = data['SalePrice'].to_numpy()
# ```
# Use
# ```python
# data_batch = data.sample(batch_size)
# data_x = data_batch['GrLivArea'].to_numpy()
# data_y = data_batch['SalePrice'].to_numpy()
# ```
#
# You also have to adjust the loop_N accordingly to make sure that it loop over the entire datasets the same number of times.
# ```python
# loop_N = 30*len(data)//batch_size
# ```
#
# Please plot your learning curve for different batch size, such as 32, 64, 128, 256, 512.
#
# ## Learning rate issue (Bonus)
# As described above, if the learning rate is too large, it will affect the convergence. Do your training with (batch_size = 64, learning_rate_m = 1e-7, learning_rate_b = 1e-1). Then linearly increase the batch size and learning rate until you see the training does not converge.
# ```
# (64, 1e-7, 1e-1)*1
# (64, 1e-7, 1e-1)*2
# (64, 1e-7, 1e-1)*4
# (64, 1e-7, 1e-1)*8
# ...
# ```
#
# **How to submit your homework**
# * Fork the github repo to your personal github
# * Make change to the 01_linear_regression_sgd.ipynb, and then push to your personal github
# * Provide the link of 01_linear_regression_sgd in the personal github.
#
# Follow the below instruction on how to do this:
# https://github.com/argonne-lcf/ai-science-training-series/blob/main/00_introToAlcf/03_githubHomework.md

# %%
#set batch_sizes that batch_size would loop through
tmp=(32, 64, 128, 256, 512)
batch_sizes = list(tmp)

# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60
# set a learning rate for each parameter
learning_rate_m = 1e-7
learning_rate_b = 1e-1
# use these to plot our progress over time
loss_history = []

# create a 1 by 2 plot grid
fig,ax = plt.subplots(len(batch_sizes),2,figsize=(18,40),dpi=80)

# convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
for j,batch_size in enumerate(batch_sizes):
  data_batch = data.sample(batch_size)
  data_x = data_batch['GrLivArea'].to_numpy()
  data_y = data_batch['SalePrice'].to_numpy()
  # we run our loop N times
  loop_N = 30*len(data)//batch_size
  for i in range(loop_N):
    # update our slope and intercept based on the current values
    m = updated_m(data_x,data_y,m,b,learning_rate_m)
    b = updated_b(data_x,data_y,m,b,learning_rate_b)

    # calculate the loss value
    loss_value = np.mean(loss(data_x,data_y,m,b))

    # keep a history of our loss values
    loss_history.append(loss_value)

    # print our progress
    print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))

    # close/delete previous plots
    # plt.close('all')

    # lot our usual output
    plot_data(data_x,data_y,m,b,ax[j,0])

    # here we also plot the calculated linear fit for comparison
    line_x = np.arange(data_x.min(),data_x.max())
    line_y = line_x * m_calc + b_calc
    ax[j,0].plot(line_x,line_y,'b-',label='calculated')
    # add a legend to the plot and x/y labels
    #ax[j,0].legend()
    ax[j,0].set_xlabel('square footage')
    ax[j,0].set_ylabel('sale price')

    # plot the loss
    loss_x = np.arange(0,len(loss_history))
    loss_y = np.asarray(loss_history)
    ax[j,1].plot(loss_x,loss_y, 'o-')
    ax[j,1].set_yscale('log')
    ax[j,1].set_xlabel('loop step')
    ax[j,1].set_ylabel('loss')

    # gives us time to see the plot
    #time.sleep(2.5)
    # clears the plot when the next plot is ready to show.
    #ipydis.clear_output(wait=True)
plt.show()
# Out:
# [000]  dy_i = 49.57 * x + 18395.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 6631001504.611814
# [001]  dy_i = 70.06 * x + 26642.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2728635504.028508
# [002]  dy_i = 79.41 * x + 30653.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1898940884.784129
# [003]  dy_i = 83.61 * x + 32701.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1723191279.451712
# [004]  dy_i = 85.42 * x + 33836.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1685752824.187675
# [005]  dy_i = 86.14 * x + 34547.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1677190920.028756
# [006]  dy_i = 86.35 * x + 35057.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1674502773.631415
# [007]  dy_i = 86.33 * x + 35471.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1672954673.758144
# [008]  dy_i = 86.20 * x + 35838.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1671618727.183907
# [009]  dy_i = 86.03 * x + 36179.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1670334273.267614
# [010]  dy_i = 85.83 * x + 36505.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1669083402.073900
# [011]  dy_i = 85.63 * x + 36822.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1667869039.415379
# [012]  dy_i = 85.43 * x + 37130.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1666694184.449030
# [013]  dy_i = 85.23 * x + 37433.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1665559885.704388
# [014]  dy_i = 85.04 * x + 37729.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1664465905.794610
# [015]  dy_i = 84.84 * x + 38020.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1663411361.351168
# [016]  dy_i = 84.65 * x + 38305.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1662395085.120709
# [017]  dy_i = 84.46 * x + 38585.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1661415804.868329
# [018]  dy_i = 84.28 * x + 38860.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1660472226.916616
# [019]  dy_i = 84.10 * x + 39129.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1659563073.802543
# [020]  dy_i = 83.92 * x + 39394.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1658687100.575637
# [021]  dy_i = 83.75 * x + 39654.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1657843101.312088
# [022]  dy_i = 83.58 * x + 39909.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1657029911.193766
# [023]  dy_i = 83.41 * x + 40159.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1656246406.600118
# [024]  dy_i = 83.25 * x + 40405.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1655491504.327676
# [025]  dy_i = 83.09 * x + 40646.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1654764160.443177
# [026]  dy_i = 82.93 * x + 40883.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1654063368.999197
# [027]  dy_i = 82.77 * x + 41115.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1653388160.715206
# [028]  dy_i = 82.62 * x + 41343.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1652737601.669771
# [029]  dy_i = 82.47 * x + 41567.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1652110792.023714
# [030]  dy_i = 82.32 * x + 41787.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1651506864.782241
# [031]  dy_i = 82.18 * x + 42003.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1650924984.598807
# [032]  dy_i = 82.04 * x + 42214.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1650364346.621065
# [033]  dy_i = 81.90 * x + 42422.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1649824175.378234
# [034]  dy_i = 81.76 * x + 42626.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1649303723.708766
# [035]  dy_i = 81.63 * x + 42827.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1648802271.727002
# [036]  dy_i = 81.50 * x + 43023.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1648319125.827492
# [037]  dy_i = 81.37 * x + 43216.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1647853617.725632
# [038]  dy_i = 81.24 * x + 43405.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1647405103.533307
# [039]  dy_i = 81.12 * x + 43591.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1646972962.868276
# [040]  dy_i = 81.00 * x + 43774.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1646556597.996063
# [041]  dy_i = 80.88 * x + 43953.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1646155433.003178
# [042]  dy_i = 80.76 * x + 44129.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1645768913.000515
# [043]  dy_i = 80.64 * x + 44301.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1645396503.355836
# [044]  dy_i = 80.53 * x + 44471.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1645037688.954266
# [045]  dy_i = 80.42 * x + 44637.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1644691973.485793
# [046]  dy_i = 80.31 * x + 44800.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1644358878.758774
# [047]  dy_i = 80.20 * x + 44961.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1644037944.038504
# [048]  dy_i = 80.10 * x + 45118.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1643728725.409925
# [049]  dy_i = 79.99 * x + 45272.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1643430795.163615
# [050]  dy_i = 79.89 * x + 45424.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1643143741.204175
# [051]  dy_i = 79.79 * x + 45572.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1642867166.480220
# [052]  dy_i = 79.70 * x + 45718.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1642600688.435188
# [053]  dy_i = 79.60 * x + 45862.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1642343938.478183
# [054]  dy_i = 79.51 * x + 46002.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1642096561.474144
# [055]  dy_i = 79.41 * x + 46140.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641858215.252626
# [056]  dy_i = 79.32 * x + 46276.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641628570.134508
# [057]  dy_i = 79.23 * x + 46409.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641407308.475987
# [058]  dy_i = 79.15 * x + 46540.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1641194124.229213
# [059]  dy_i = 79.06 * x + 46668.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640988722.518964
# [060]  dy_i = 78.98 * x + 46794.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640790819.234777
# [061]  dy_i = 78.89 * x + 46917.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640600140.637973
# [062]  dy_i = 78.81 * x + 47038.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640416422.983013
# [063]  dy_i = 78.73 * x + 47157.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640239412.152699
# [064]  dy_i = 78.66 * x + 47274.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640068863.306668
# [065]  dy_i = 78.58 * x + 47389.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639904540.542740
# [066]  dy_i = 78.50 * x + 47501.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639746216.570616
# [067]  dy_i = 78.43 * x + 47612.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639593672.397488
# [068]  dy_i = 78.36 * x + 47720.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639446697.025139
# [069]  dy_i = 78.29 * x + 47827.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639305087.158078
# [070]  dy_i = 78.22 * x + 47931.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639168646.922354
# [071]  dy_i = 78.15 * x + 48034.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1639037187.594620
# [072]  dy_i = 78.08 * x + 48134.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638910527.341091
# [073]  dy_i = 78.01 * x + 48233.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638788490.966034
# [074]  dy_i = 77.95 * x + 48330.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638670909.669439
# [075]  dy_i = 77.89 * x + 48425.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638557620.813535
# [076]  dy_i = 77.82 * x + 48519.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638448467.697829
# [077]  dy_i = 77.76 * x + 48610.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638343299.342360
# [078]  dy_i = 77.70 * x + 48700.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638241970.278866
# [079]  dy_i = 77.64 * x + 48789.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638144340.349570
# [080]  dy_i = 77.59 * x + 48875.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638050274.513316
# [081]  dy_i = 77.53 * x + 48961.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637959642.658782
# [082]  dy_i = 77.47 * x + 49044.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637872319.424509
# [083]  dy_i = 77.42 * x + 49126.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637788184.025503
# [084]  dy_i = 77.36 * x + 49207.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637707120.086164
# [085]  dy_i = 77.31 * x + 49286.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637629015.479320
# [086]  dy_i = 77.26 * x + 49363.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637553762.171129
# [087]  dy_i = 77.21 * x + 49440.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637481256.071648
# [088]  dy_i = 77.16 * x + 49514.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637411396.890858
# [089]  dy_i = 77.11 * x + 49588.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637344087.999944
# [090]  dy_i = 77.06 * x + 49660.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637279236.297634
# [091]  dy_i = 77.01 * x + 49730.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637216752.081430
# [092]  dy_i = 76.97 * x + 49800.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637156548.923522
# [093]  dy_i = 76.92 * x + 49868.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637098543.551250
# [094]  dy_i = 76.88 * x + 49935.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1637042655.731916
# [095]  dy_i = 76.83 * x + 50000.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636988808.161813
# [096]  dy_i = 76.79 * x + 50065.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636936926.359291
# [097]  dy_i = 76.75 * x + 50128.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636886938.561740
# [098]  dy_i = 76.71 * x + 50190.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636838775.626326
# [099]  dy_i = 76.67 * x + 50251.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636792370.934355
# [100]  dy_i = 76.63 * x + 50311.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636747660.299124
# [101]  dy_i = 76.59 * x + 50369.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636704581.877141
# [102]  dy_i = 76.55 * x + 50427.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636663076.082581
# [103]  dy_i = 76.51 * x + 50484.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636623085.504867
# [104]  dy_i = 76.47 * x + 50539.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636584554.829263
# [105]  dy_i = 76.44 * x + 50594.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636547430.760361
# [106]  dy_i = 76.40 * x + 50647.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636511661.948363
# [107]  dy_i = 76.37 * x + 50700.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636477198.918053
# [108]  dy_i = 76.33 * x + 50751.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636443994.000369
# [109]  dy_i = 76.30 * x + 50802.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636412001.266457
# [110]  dy_i = 76.26 * x + 50851.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636381176.464153
# [111]  dy_i = 76.23 * x + 50900.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636351476.956769
# [112]  dy_i = 76.20 * x + 50948.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636322861.664118
# [113]  dy_i = 76.17 * x + 50995.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636295291.005690
# [114]  dy_i = 76.14 * x + 51041.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636268726.845910
# [115]  dy_i = 76.11 * x + 51086.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636243132.441387
# [116]  dy_i = 76.08 * x + 51131.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636218472.390086
# [117]  dy_i = 76.05 * x + 51174.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636194712.582368
# [118]  dy_i = 76.02 * x + 51217.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636171820.153802
# [119]  dy_i = 75.99 * x + 51259.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636149763.439714
# [120]  dy_i = 75.96 * x + 51300.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636128511.931384
# [121]  dy_i = 75.94 * x + 51341.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636108036.233848
# [122]  dy_i = 75.91 * x + 51380.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636088308.025239
# [123]  dy_i = 75.88 * x + 51419.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636069300.017614
# [124]  dy_i = 75.86 * x + 51458.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636050985.919204
# [125]  dy_i = 75.83 * x + 51495.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636033340.398057
# [126]  dy_i = 75.81 * x + 51532.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636016339.046987
# [127]  dy_i = 75.78 * x + 51568.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635999958.349823
# [128]  dy_i = 75.76 * x + 51604.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635984175.648880
# [129]  dy_i = 75.74 * x + 51639.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635968969.113618
# [130]  dy_i = 75.71 * x + 51673.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635954317.710444
# [131]  dy_i = 75.69 * x + 51707.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635940201.173623
# [132]  dy_i = 75.67 * x + 51740.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635926599.977241
# [133]  dy_i = 75.65 * x + 51772.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635913495.308200
# [134]  dy_i = 75.63 * x + 51804.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635900869.040202
# [135]  dy_i = 75.61 * x + 51835.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635888703.708662
# [136]  dy_i = 75.59 * x + 51866.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635876982.486565
# [137]  dy_i = 75.57 * x + 51896.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635865689.161184
# [138]  dy_i = 75.55 * x + 51925.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635854808.111656
# [139]  dy_i = 75.53 * x + 51954.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635844324.287377
# [140]  dy_i = 75.51 * x + 51983.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635834223.187181
# [141]  dy_i = 75.49 * x + 52010.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635824490.839284
# [142]  dy_i = 75.47 * x + 52038.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635815113.781960
# [143]  dy_i = 75.45 * x + 52065.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635806079.044915
# [144]  dy_i = 75.44 * x + 52091.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635797374.131355
# [145]  dy_i = 75.42 * x + 52117.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635788987.000693
# [146]  dy_i = 75.40 * x + 52142.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635780906.051898
# [147]  dy_i = 75.38 * x + 52167.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635773120.107448
# [148]  dy_i = 75.37 * x + 52192.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635765618.397870
# [149]  dy_i = 75.35 * x + 52216.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635758390.546842
# [150]  dy_i = 75.34 * x + 52239.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635751426.556843
# [151]  dy_i = 75.32 * x + 52263.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635744716.795322
# [152]  dy_i = 75.31 * x + 52285.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635738251.981375
# [153]  dy_i = 75.29 * x + 52308.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635732023.172909
# [154]  dy_i = 75.28 * x + 52330.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635726021.754272
# [155]  dy_i = 75.26 * x + 52351.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635720239.424335
# [156]  dy_i = 75.25 * x + 52372.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635714668.185015
# [157]  dy_i = 75.23 * x + 52393.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635709300.330204
# [158]  dy_i = 75.22 * x + 52413.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635704128.435118
# [159]  dy_i = 75.21 * x + 52433.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635699145.346019
# [160]  dy_i = 75.19 * x + 52453.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635694344.170329
# [161]  dy_i = 75.18 * x + 52472.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635689718.267088
# [162]  dy_i = 75.17 * x + 52491.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635685261.237775
# [163]  dy_i = 75.16 * x + 52510.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635680966.917451
# [164]  dy_i = 75.14 * x + 52528.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635676829.366238
# [165]  dy_i = 75.13 * x + 52546.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635672842.861099
# [166]  dy_i = 75.12 * x + 52563.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635669001.887922
# [167]  dy_i = 75.11 * x + 52580.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635665301.133896
# [168]  dy_i = 75.10 * x + 52597.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635661735.480160
# [169]  dy_i = 75.09 * x + 52614.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635658299.994720
# [170]  dy_i = 75.08 * x + 52630.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635654989.925635
# [171]  dy_i = 75.06 * x + 52646.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635651800.694434
# [172]  dy_i = 75.05 * x + 52662.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635648727.889793
# [173]  dy_i = 75.04 * x + 52677.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635645767.261425
# [174]  dy_i = 75.03 * x + 52692.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635642914.714207
# [175]  dy_i = 75.02 * x + 52707.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635640166.302511
# [176]  dy_i = 75.01 * x + 52722.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635637518.224750
# [177]  dy_i = 75.00 * x + 52736.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635634966.818119
# [178]  dy_i = 75.00 * x + 52750.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635632508.553525
# [179]  dy_i = 74.99 * x + 52764.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635630140.030714
# [180]  dy_i = 74.98 * x + 52777.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635627857.973556
# [181]  dy_i = 74.97 * x + 52790.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635625659.225523
# [182]  dy_i = 74.96 * x + 52803.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635623540.745321
# [183]  dy_i = 74.95 * x + 52816.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635621499.602678
# [184]  dy_i = 74.94 * x + 52829.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635619532.974299
# [185]  dy_i = 74.93 * x + 52841.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635617638.139956
# [186]  dy_i = 74.93 * x + 52853.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635615812.478722
# [187]  dy_i = 74.92 * x + 52865.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635614053.465356
# [188]  dy_i = 74.91 * x + 52877.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635612358.666798
# [189]  dy_i = 74.90 * x + 52888.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635610725.738814
# [190]  dy_i = 74.90 * x + 52899.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635609152.422748
# [191]  dy_i = 74.89 * x + 52910.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635607636.542397
# [192]  dy_i = 74.88 * x + 52921.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635606176.001005
# [193]  dy_i = 74.87 * x + 52932.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635604768.778359
# [194]  dy_i = 74.87 * x + 52942.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635603412.927996
# [195]  dy_i = 74.86 * x + 52952.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635602106.574514
# [196]  dy_i = 74.85 * x + 52962.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635600847.910970
# [197]  dy_i = 74.85 * x + 52972.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635599635.196388
# [198]  dy_i = 74.84 * x + 52982.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635598466.753350
# [199]  dy_i = 74.83 * x + 52991.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635597340.965671
# [200]  dy_i = 74.83 * x + 53001.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635596256.276168
# [201]  dy_i = 74.82 * x + 53010.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635595211.184505
# [202]  dy_i = 74.82 * x + 53019.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635594204.245117
# [203]  dy_i = 74.81 * x + 53028.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635593234.065211
# [204]  dy_i = 74.80 * x + 53036.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635592299.302841
# [205]  dy_i = 74.80 * x + 53045.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635591398.665048
# [206]  dy_i = 74.79 * x + 53053.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635590530.906075
# [207]  dy_i = 74.79 * x + 53061.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635589694.825643
# [208]  dy_i = 74.78 * x + 53069.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635588889.267290
# [209]  dy_i = 74.78 * x + 53077.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635588113.116774
# [210]  dy_i = 74.77 * x + 53085.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635587365.300525
# [211]  dy_i = 74.77 * x + 53092.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635586644.784171
# [212]  dy_i = 74.76 * x + 53100.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635585950.571096
# [213]  dy_i = 74.76 * x + 53107.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635585281.701069
# [214]  dy_i = 74.75 * x + 53114.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635584637.248913
# [215]  dy_i = 74.75 * x + 53121.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635584016.323225
# [216]  dy_i = 74.74 * x + 53128.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635583418.065146
# [217]  dy_i = 74.74 * x + 53135.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635582841.647166
# [218]  dy_i = 74.73 * x + 53142.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635582286.271989
# [219]  dy_i = 74.73 * x + 53148.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635581751.171422
# [220]  dy_i = 74.72 * x + 53155.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635581235.605318
# [221]  dy_i = 74.72 * x + 53161.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635580738.860549
# [222]  dy_i = 74.72 * x + 53167.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635580260.250020
# [223]  dy_i = 74.71 * x + 53173.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635579799.111719
# [224]  dy_i = 74.71 * x + 53179.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635579354.807804
# [225]  dy_i = 74.70 * x + 53185.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635578926.723714
# [226]  dy_i = 74.70 * x + 53191.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635578514.267328
# [227]  dy_i = 74.70 * x + 53197.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635578116.868137
# [228]  dy_i = 74.69 * x + 53202.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635577733.976461
# [229]  dy_i = 74.69 * x + 53208.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635577365.062687
# [230]  dy_i = 74.69 * x + 53213.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635577009.616536
# [231]  dy_i = 74.68 * x + 53218.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635576667.146356
# [232]  dy_i = 74.68 * x + 53223.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635576337.178444
# [233]  dy_i = 74.68 * x + 53228.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635576019.256391
# [234]  dy_i = 74.67 * x + 53233.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635575712.940449
# [235]  dy_i = 74.67 * x + 53238.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635575417.806923
# [236]  dy_i = 74.67 * x + 53243.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635575133.447586
# [237]  dy_i = 74.66 * x + 53248.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635574859.469115
# [238]  dy_i = 74.66 * x + 53252.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635574595.492543
# [239]  dy_i = 74.66 * x + 53257.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635574341.152740
# [240]  dy_i = 74.65 * x + 53261.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635574096.097905
# [241]  dy_i = 74.65 * x + 53265.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635573859.989079
# [242]  dy_i = 74.65 * x + 53270.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635573632.499677
# [243]  dy_i = 74.64 * x + 53274.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635573413.315039
# [244]  dy_i = 74.64 * x + 53278.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635573202.131988
# [245]  dy_i = 74.64 * x + 53282.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572998.658417
# [246]  dy_i = 74.64 * x + 53286.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572802.612884
# [247]  dy_i = 74.63 * x + 53290.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572613.724218
# [248]  dy_i = 74.63 * x + 53294.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572431.731151
# [249]  dy_i = 74.63 * x + 53297.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572256.381951
# [250]  dy_i = 74.63 * x + 53301.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635572087.434075
# [251]  dy_i = 74.62 * x + 53305.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571924.653836
# [252]  dy_i = 74.62 * x + 53308.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571767.816077
# [253]  dy_i = 74.62 * x + 53312.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571616.703861
# [254]  dy_i = 74.62 * x + 53315.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571471.108171
# [255]  dy_i = 74.61 * x + 53318.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571330.827619
# [256]  dy_i = 74.61 * x + 53322.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571195.668170
# [257]  dy_i = 74.61 * x + 53325.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635571065.442873
# [258]  dy_i = 74.61 * x + 53328.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570939.971600
# [259]  dy_i = 74.61 * x + 53331.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570819.080801
# [260]  dy_i = 74.60 * x + 53334.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570702.603259
# [261]  dy_i = 74.60 * x + 53337.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570590.377864
# [262]  dy_i = 74.60 * x + 53340.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570482.249387
# [263]  dy_i = 74.60 * x + 53343.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570378.068264
# [264]  dy_i = 74.60 * x + 53346.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570277.690393
# [265]  dy_i = 74.59 * x + 53349.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570180.976932
# [266]  dy_i = 74.59 * x + 53352.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635570087.794108
# [267]  dy_i = 74.59 * x + 53354.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569998.013029
# [268]  dy_i = 74.59 * x + 53357.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569911.509513
# [269]  dy_i = 74.59 * x + 53359.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569828.163907
# [270]  dy_i = 74.59 * x + 53362.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569747.860928
# [271]  dy_i = 74.58 * x + 53364.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569670.489502
# [272]  dy_i = 74.58 * x + 53367.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569595.942609
# [273]  dy_i = 74.58 * x + 53369.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569524.117136
# [274]  dy_i = 74.58 * x + 53372.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569454.913735
# [275]  dy_i = 74.58 * x + 53374.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569388.236683
# [276]  dy_i = 74.58 * x + 53376.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569323.993755
# [277]  dy_i = 74.57 * x + 53378.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569262.096089
# [278]  dy_i = 74.57 * x + 53381.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569202.458067
# [279]  dy_i = 74.57 * x + 53383.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569144.997201
# [280]  dy_i = 74.57 * x + 53385.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569089.634010
# [281]  dy_i = 74.57 * x + 53387.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635569036.291916
# [282]  dy_i = 74.57 * x + 53389.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568984.897137
# [283]  dy_i = 74.57 * x + 53391.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568935.378583
# [284]  dy_i = 74.57 * x + 53393.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568887.667761
# [285]  dy_i = 74.56 * x + 53395.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568841.698677
# [286]  dy_i = 74.56 * x + 53397.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568797.407748
# [287]  dy_i = 74.56 * x + 53399.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568754.733710
# [288]  dy_i = 74.56 * x + 53400.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568713.617537
# [289]  dy_i = 74.56 * x + 53402.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568674.002358
# [290]  dy_i = 74.56 * x + 53404.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568635.833376
# [291]  dy_i = 74.56 * x + 53406.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568599.057797
# [292]  dy_i = 74.56 * x + 53407.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568563.624753
# [293]  dy_i = 74.55 * x + 53409.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568529.485233
# [294]  dy_i = 74.55 * x + 53411.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568496.592015
# [295]  dy_i = 74.55 * x + 53412.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568464.899602
# [296]  dy_i = 74.55 * x + 53414.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568434.364158
# [297]  dy_i = 74.55 * x + 53415.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568404.943444
# [298]  dy_i = 74.55 * x + 53417.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568376.596768
# [299]  dy_i = 74.55 * x + 53418.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568349.284920
# [300]  dy_i = 74.55 * x + 53420.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568322.970122
# [301]  dy_i = 74.55 * x + 53421.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568297.615977
# [302]  dy_i = 74.55 * x + 53422.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568273.187413
# [303]  dy_i = 74.54 * x + 53424.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568249.650643
# [304]  dy_i = 74.54 * x + 53425.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568226.973109
# [305]  dy_i = 74.54 * x + 53427.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568205.123445
# [306]  dy_i = 74.54 * x + 53428.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568184.071428
# [307]  dy_i = 74.54 * x + 53429.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568163.787940
# [308]  dy_i = 74.54 * x + 53430.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568144.244923
# [309]  dy_i = 74.54 * x + 53432.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568125.415346
# [310]  dy_i = 74.54 * x + 53433.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568107.273166
# [311]  dy_i = 74.54 * x + 53434.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568089.793286
# [312]  dy_i = 74.54 * x + 53435.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568072.951529
# [313]  dy_i = 74.54 * x + 53436.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568056.724601
# [314]  dy_i = 74.54 * x + 53437.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568041.090055
# [315]  dy_i = 74.53 * x + 53438.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568026.026266
# [316]  dy_i = 74.53 * x + 53440.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635568011.512397
# [317]  dy_i = 74.53 * x + 53441.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567997.528375
# [318]  dy_i = 74.53 * x + 53442.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567984.054855
# [319]  dy_i = 74.53 * x + 53443.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567971.073202
# [320]  dy_i = 74.53 * x + 53444.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567958.565459
# [321]  dy_i = 74.53 * x + 53445.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567946.514325
# [322]  dy_i = 74.53 * x + 53446.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567934.903132
# [323]  dy_i = 74.53 * x + 53447.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567923.715819
# [324]  dy_i = 74.53 * x + 53447.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567912.936911
# [325]  dy_i = 74.53 * x + 53448.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567902.551500
# [326]  dy_i = 74.53 * x + 53449.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567892.545221
# [327]  dy_i = 74.53 * x + 53450.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567882.904233
# [328]  dy_i = 74.53 * x + 53451.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567873.615199
# [329]  dy_i = 74.53 * x + 53452.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567864.665273
# [330]  dy_i = 74.53 * x + 53453.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567856.042073
# [331]  dy_i = 74.52 * x + 53454.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567847.733674
# [332]  dy_i = 74.52 * x + 53454.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567839.728583
# [333]  dy_i = 74.52 * x + 53455.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567832.015726
# [334]  dy_i = 74.52 * x + 53456.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567824.584437
# [335]  dy_i = 74.52 * x + 53457.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567817.424434
# [336]  dy_i = 74.52 * x + 53457.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567810.525816
# [337]  dy_i = 74.52 * x + 53458.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567803.879041
# [338]  dy_i = 74.52 * x + 53459.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567797.474913
# [339]  dy_i = 74.52 * x + 53460.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567791.304575
# [340]  dy_i = 74.52 * x + 53460.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567785.359493
# [341]  dy_i = 74.52 * x + 53461.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567779.631442
# [342]  dy_i = 74.52 * x + 53462.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567774.112502
# [343]  dy_i = 74.52 * x + 53462.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567768.795036
# [344]  dy_i = 74.52 * x + 53463.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567763.671690
# [345]  dy_i = 74.52 * x + 53463.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567758.735378
# [346]  dy_i = 74.52 * x + 53464.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567753.979272
# [347]  dy_i = 74.52 * x + 53465.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567749.396793
# [348]  dy_i = 74.52 * x + 53465.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567744.981602
# [349]  dy_i = 74.52 * x + 53466.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567740.727593
# [350]  dy_i = 74.52 * x + 53466.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567736.628882
# [351]  dy_i = 74.52 * x + 53467.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567732.679799
# [352]  dy_i = 74.52 * x + 53468.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567728.874882
# [353]  dy_i = 74.51 * x + 53468.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567725.208867
# [354]  dy_i = 74.51 * x + 53469.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567721.676685
# [355]  dy_i = 74.51 * x + 53469.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567718.273448
# [356]  dy_i = 74.51 * x + 53470.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567714.994452
# [357]  dy_i = 74.51 * x + 53470.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567711.835158
# [358]  dy_i = 74.51 * x + 53471.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567708.791199
# [359]  dy_i = 74.51 * x + 53471.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567705.858362
# [360]  dy_i = 74.51 * x + 53472.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567703.032592
# [361]  dy_i = 74.51 * x + 53472.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567700.309981
# [362]  dy_i = 74.51 * x + 53473.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567697.686761
# [363]  dy_i = 74.51 * x + 53473.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567695.159304
# [364]  dy_i = 74.51 * x + 53473.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567692.724116
# [365]  dy_i = 74.51 * x + 53474.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567690.377827
# [366]  dy_i = 74.51 * x + 53474.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567688.117192
# [367]  dy_i = 74.51 * x + 53475.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567685.939084
# [368]  dy_i = 74.51 * x + 53475.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567683.840490
# [369]  dy_i = 74.51 * x + 53476.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567681.818508
# [370]  dy_i = 74.51 * x + 53476.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567679.870341
# [371]  dy_i = 74.51 * x + 53476.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567677.993294
# [372]  dy_i = 74.51 * x + 53477.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567676.184770
# [373]  dy_i = 74.51 * x + 53477.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567674.442269
# [374]  dy_i = 74.51 * x + 53477.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567672.763380
# [375]  dy_i = 74.51 * x + 53478.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567671.145780
# [376]  dy_i = 74.51 * x + 53478.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567669.587233
# [377]  dy_i = 74.51 * x + 53478.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567668.085582
# [378]  dy_i = 74.51 * x + 53479.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567666.638751
# [379]  dy_i = 74.51 * x + 53479.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567665.244739
# [380]  dy_i = 74.51 * x + 53479.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567663.901616
# [381]  dy_i = 74.51 * x + 53480.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567662.607525
# [382]  dy_i = 74.51 * x + 53480.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567661.360677
# [383]  dy_i = 74.51 * x + 53480.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567660.159347
# [384]  dy_i = 74.51 * x + 53481.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567659.001872
# [385]  dy_i = 74.51 * x + 53481.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567657.886652
# [386]  dy_i = 74.51 * x + 53481.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567656.812145
# [387]  dy_i = 74.51 * x + 53482.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567655.776864
# [388]  dy_i = 74.51 * x + 53482.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567654.779377
# [389]  dy_i = 74.51 * x + 53482.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567653.818304
# [390]  dy_i = 74.51 * x + 53482.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567652.892316
# [391]  dy_i = 74.51 * x + 53483.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567652.000133
# [392]  dy_i = 74.50 * x + 53483.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567651.140519
# [393]  dy_i = 74.50 * x + 53483.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567650.312288
# [394]  dy_i = 74.50 * x + 53483.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567649.514291
# [395]  dy_i = 74.50 * x + 53484.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567648.745427
# [396]  dy_i = 74.50 * x + 53484.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567648.004630
# [397]  dy_i = 74.50 * x + 53484.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567647.290878
# [398]  dy_i = 74.50 * x + 53484.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567646.603181
# [399]  dy_i = 74.50 * x + 53485.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567645.940590
# [400]  dy_i = 74.50 * x + 53485.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567645.302187
# [401]  dy_i = 74.50 * x + 53485.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567644.687090
# [402]  dy_i = 74.50 * x + 53485.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567644.094448
# [403]  dy_i = 74.50 * x + 53486.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567643.523441
# [404]  dy_i = 74.50 * x + 53486.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567642.973279
# [405]  dy_i = 74.50 * x + 53486.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567642.443202
# [406]  dy_i = 74.50 * x + 53486.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567641.932476
# [407]  dy_i = 74.50 * x + 53486.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567641.440393
# [408]  dy_i = 74.50 * x + 53487.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567640.966276
# [409]  dy_i = 74.50 * x + 53487.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567640.509467
# [410]  dy_i = 74.50 * x + 53487.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567640.069334
# [411]  dy_i = 74.50 * x + 53487.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567639.645268
# [412]  dy_i = 74.50 * x + 53487.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1635567639.236683
# ...
# [088]  dy_i = 67.15 * x + 60450.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153852436.666167
# [089]  dy_i = 67.11 * x + 60504.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153815924.416367
# [090]  dy_i = 67.08 * x + 60557.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153780756.259070
# [091]  dy_i = 67.04 * x + 60609.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153746882.715413
# [092]  dy_i = 67.01 * x + 60660.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153714256.127951
# [093]  dy_i = 66.97 * x + 60710.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153682830.593613
# [094]  dy_i = 66.94 * x + 60759.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153652561.899112
# [095]  dy_i = 66.91 * x + 60808.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153623407.458749
# [096]  dy_i = 66.88 * x + 60855.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153595326.254490
# [097]  dy_i = 66.85 * x + 60902.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153568278.778264
# [098]  dy_i = 66.82 * x + 60947.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153542226.976373
# [099]  dy_i = 66.79 * x + 60992.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153517134.195957
# [100]  dy_i = 66.76 * x + 61036.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153492965.133423
# [101]  dy_i = 66.73 * x + 61079.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153469685.784778
# [102]  dy_i = 66.70 * x + 61122.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153447263.397789
# [103]  dy_i = 66.67 * x + 61163.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153425666.425897
# [104]  dy_i = 66.64 * x + 61204.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153404864.483844
# [105]  dy_i = 66.62 * x + 61244.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153384828.304913
# [106]  dy_i = 66.59 * x + 61283.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153365529.699756
# [107]  dy_i = 66.56 * x + 61322.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153346941.516736
# [108]  dy_i = 66.54 * x + 61360.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153329037.603724
# [109]  dy_i = 66.51 * x + 61397.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153311792.771306
# [110]  dy_i = 66.49 * x + 61433.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153295182.757342
# [111]  dy_i = 66.47 * x + 61469.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153279184.192834
# [112]  dy_i = 66.44 * x + 61504.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153263774.569045
# [113]  dy_i = 66.42 * x + 61539.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153248932.205831
# [114]  dy_i = 66.40 * x + 61573.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153234636.221140
# [115]  dy_i = 66.38 * x + 61606.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153220866.501633
# [116]  dy_i = 66.35 * x + 61638.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153207603.674385
# [117]  dy_i = 66.33 * x + 61670.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153194829.079629
# [118]  dy_i = 66.31 * x + 61702.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153182524.744502
# [119]  dy_i = 66.29 * x + 61732.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153170673.357760
# [120]  dy_i = 66.27 * x + 61763.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153159258.245425
# [121]  dy_i = 66.25 * x + 61792.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153148263.347319
# [122]  dy_i = 66.23 * x + 61821.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153137673.194475
# [123]  dy_i = 66.21 * x + 61850.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153127472.887372
# [124]  dy_i = 66.19 * x + 61878.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153117648.074970
# [125]  dy_i = 66.18 * x + 61906.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153108184.934521
# [126]  dy_i = 66.16 * x + 61933.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153099070.152122
# [127]  dy_i = 66.14 * x + 61959.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153090290.903982
# [128]  dy_i = 66.12 * x + 61985.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1153081834.838382
# [000]  dy_i = 67.29 * x + 61739.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1672164641.939200
# [001]  dy_i = 68.01 * x + 61344.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1666777892.141202
# [002]  dy_i = 68.51 * x + 60887.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1662906290.308123
# [003]  dy_i = 68.92 * x + 60408.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1659552364.996730
# [004]  dy_i = 69.28 * x + 59925.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1656454095.353756
# [005]  dy_i = 69.61 * x + 59446.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1653529787.644166
# [006]  dy_i = 69.93 * x + 58974.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1650747907.007063
# [007]  dy_i = 70.24 * x + 58512.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1648093146.034828
# [008]  dy_i = 70.53 * x + 58059.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1645556256.047831
# [009]  dy_i = 70.83 * x + 57616.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1643130535.505601
# [010]  dy_i = 71.11 * x + 57183.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1640810474.028064
# [011]  dy_i = 71.39 * x + 56758.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1638591188.748613
# [012]  dy_i = 71.66 * x + 56344.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1636468178.468866
# [013]  dy_i = 71.93 * x + 55938.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1634437211.942175
# [014]  dy_i = 72.19 * x + 55541.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1632494274.361788
# [015]  dy_i = 72.44 * x + 55153.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1630635539.531719
# [016]  dy_i = 72.69 * x + 54773.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1628857353.536113
# [017]  dy_i = 72.93 * x + 54402.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1627156223.663622
# [018]  dy_i = 73.17 * x + 54038.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625528809.823492
# [019]  dy_i = 73.40 * x + 53683.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1623971917.224188
# [020]  dy_i = 73.63 * x + 53335.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1622482489.763635
# [021]  dy_i = 73.85 * x + 52996.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1621057603.880524
# [022]  dy_i = 74.07 * x + 52663.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1619694462.749413
# [023]  dy_i = 74.28 * x + 52338.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1618390390.761631
# [024]  dy_i = 74.49 * x + 52020.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1617142828.260510
# [025]  dy_i = 74.70 * x + 51709.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1615949326.511495
# [026]  dy_i = 74.89 * x + 51404.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1614807542.893160
# [027]  dy_i = 75.09 * x + 51107.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1613715236.297967
# [028]  dy_i = 75.28 * x + 50816.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1612670262.732876
# [029]  dy_i = 75.47 * x + 50531.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1611670571.110878
# [030]  dy_i = 75.65 * x + 50253.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1610714199.224989
# [031]  dy_i = 75.83 * x + 49980.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1609799269.896770
# [032]  dy_i = 76.00 * x + 49714.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1608923987.291752
# [033]  dy_i = 76.17 * x + 49453.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1608086633.394548
# [034]  dy_i = 76.34 * x + 49198.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1607285564.636703
# [035]  dy_i = 76.50 * x + 48949.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1606519208.670681
# [036]  dy_i = 76.66 * x + 48705.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1605786061.283632
# [037]  dy_i = 76.82 * x + 48467.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1605084683.444916
# [038]  dy_i = 76.97 * x + 48234.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1604413698.481549
# [039]  dy_i = 77.12 * x + 48005.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1603771789.376053
# [040]  dy_i = 77.27 * x + 47782.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1603157696.181398
# [041]  dy_i = 77.41 * x + 47564.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1602570213.547967
# [042]  dy_i = 77.55 * x + 47350.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1602008188.357674
# [043]  dy_i = 77.69 * x + 47142.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1601470517.460613
# [044]  dy_i = 77.82 * x + 46937.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1600956145.509785
# [045]  dy_i = 77.95 * x + 46738.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1600464062.889645
# [046]  dy_i = 78.08 * x + 46542.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1599993303.734419
# [047]  dy_i = 78.20 * x + 46351.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1599542944.032289
# [048]  dy_i = 78.33 * x + 46164.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1599112099.811734
# [049]  dy_i = 78.45 * x + 45981.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1598699925.406459
# [050]  dy_i = 78.56 * x + 45803.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1598305611.795509
# [051]  dy_i = 78.68 * x + 45628.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1597928385.015314
# [052]  dy_i = 78.79 * x + 45457.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1597567504.640545
# [053]  dy_i = 78.90 * x + 45289.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1597222262.330798
# [054]  dy_i = 79.01 * x + 45126.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1596891980.440250
# [055]  dy_i = 79.11 * x + 44966.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1596576010.687577
# [056]  dy_i = 79.21 * x + 44809.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1596273732.883489
# [057]  dy_i = 79.31 * x + 44656.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1595984553.713423
# [058]  dy_i = 79.41 * x + 44506.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1595707905.572973
# [059]  dy_i = 79.51 * x + 44360.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1595443245.453792
# [060]  dy_i = 79.60 * x + 44216.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1595190053.877768
# [061]  dy_i = 79.69 * x + 44076.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1594947833.877382
# [062]  dy_i = 79.78 * x + 43939.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1594716110.020263
# [063]  dy_i = 79.87 * x + 43805.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1594494427.475993
# [000]  dy_i = 80.62 * x + 43934.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1502137723.861953
# [001]  dy_i = 81.00 * x + 43931.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1501032559.518932
# [002]  dy_i = 81.21 * x + 43869.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1500660311.395862
# [003]  dy_i = 81.34 * x + 43783.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1500457509.453919
# [004]  dy_i = 81.44 * x + 43687.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1500300736.950592
# [005]  dy_i = 81.52 * x + 43587.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1500160755.788746
# [006]  dy_i = 81.59 * x + 43487.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1500029675.280303
# [007]  dy_i = 81.66 * x + 43388.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499904942.223616
# [008]  dy_i = 81.73 * x + 43290.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499785536.385989
# [009]  dy_i = 81.79 * x + 43194.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499670950.735654
# [010]  dy_i = 81.85 * x + 43099.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499560874.641961
# [011]  dy_i = 81.91 * x + 43007.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499455080.933927
# [012]  dy_i = 81.97 * x + 42916.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499353381.399548
# [013]  dy_i = 82.03 * x + 42827.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499255608.129498
# [014]  dy_i = 82.09 * x + 42739.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499161605.383505
# [015]  dy_i = 82.14 * x + 42654.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1499071225.923477
# [016]  dy_i = 82.20 * x + 42570.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498984329.284790
# [017]  dy_i = 82.25 * x + 42487.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498900780.899398
# [018]  dy_i = 82.30 * x + 42407.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498820451.597500
# [019]  dy_i = 82.36 * x + 42328.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498743217.280092
# [020]  dy_i = 82.41 * x + 42250.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498668958.670950
# [021]  dy_i = 82.46 * x + 42174.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498597561.107617
# [022]  dy_i = 82.51 * x + 42099.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498528914.353410
# [023]  dy_i = 82.55 * x + 42026.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498462912.422400
# [024]  dy_i = 82.60 * x + 41954.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498399453.413648
# [025]  dy_i = 82.65 * x + 41884.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498338439.352944
# [026]  dy_i = 82.69 * x + 41815.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498279776.041131
# [027]  dy_i = 82.74 * x + 41747.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498223372.908488
# [028]  dy_i = 82.78 * x + 41681.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498169142.874825
# [029]  dy_i = 82.82 * x + 41616.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498117002.215000
# [030]  dy_i = 82.86 * x + 41552.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498066870.429644
# [031]  dy_i = 82.91 * x + 41490.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1498018670.120872

# %%
#set init_comb and k_list that batch size and  would loop through
import itertools

init_comb = [64, 1e-7, 1e-1]
k_list = [1, 2, 4, 8]
hyp_list = [[init_comb[0] * k, init_comb[1] * k, init_comb[2] * k ] for k in k_list]


# set our initial slope and intercept
m = 5.
b = 1000.
# batch_size = 60

# use these to plot our progress over time
loss_history = []

# create a 1 by 2 plot grid
fig,ax = plt.subplots(len(k_list),2,figsize=(18,40),dpi=80)

# convert panda data to numpy arrays, one for the "Ground Living Area" and one for "Sale Price"
for j, (batch_size, learning_rate_m, learning_rate_b) in enumerate(hyp_list):
  data_batch = data.sample(batch_size)
  data_x = data_batch['GrLivArea'].to_numpy()
  data_y = data_batch['SalePrice'].to_numpy()
  # we run our loop N times
  loop_N = 30*len(data)//batch_size
  for i in range(loop_N):
    # update our slope and intercept based on the current values
    m = updated_m(data_x,data_y,m,b,learning_rate_m)
    b = updated_b(data_x,data_y,m,b,learning_rate_b)

    # calculate the loss value
    loss_value = np.mean(loss(data_x,data_y,m,b))

    # keep a history of our loss values
    loss_history.append(loss_value)

    # print our progress
    print('[%03d]  dy_i = %.2f * x + %.2f     previously calculated: y_i = %.2f * x + %.2f    loss: %f' % (i,m,b,m_calc,b_calc,loss_value))

    # close/delete previous plots
    #plt.close('all')

    # lot our usual output
    plot_data(data_x,data_y,m,b,ax[j,0])

    # here we also plot the calculated linear fit for comparison
    line_x = np.arange(data_x.min(),data_x.max())
    line_y = line_x * m_calc + b_calc
    ax[j,0].plot(line_x,line_y,'b-',label='calculated')
    # add a legend to the plot and x/y labels
    #ax[j,0].legend()
    ax[j,0].set_xlabel('square footage')
    ax[j,0].set_ylabel('sale price')

    # plot the loss
    loss_x = np.arange(0,len(loss_history))
    loss_y = np.asarray(loss_history)
    ax[j,1].plot(loss_x,loss_y, 'o-')
    ax[j,1].set_yscale('log')
    ax[j,1].set_xlabel('loop step')
    ax[j,1].set_ylabel('loss')

    # gives us time to see the plot
    #time.sleep(2.5)
    # clears the plot when the next plot is ready to show.
    #ipydis.clear_output(wait=True)
plt.show()
# Out:
# [000]  dy_i = 53.69 * x + 17070.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 5732819492.164667
# [001]  dy_i = 74.06 * x + 23895.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2166907068.910469
# [002]  dy_i = 82.56 * x + 26839.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1541649831.595069
# [003]  dy_i = 86.07 * x + 28155.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1432473886.932425
# [004]  dy_i = 87.49 * x + 28785.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1413513746.595327
# [005]  dy_i = 88.04 * x + 29127.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1410179508.693712
# [006]  dy_i = 88.22 * x + 29347.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1409494248.380628
# [007]  dy_i = 88.25 * x + 29514.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1409236476.493985
# [008]  dy_i = 88.22 * x + 29658.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1409040944.694602
# [009]  dy_i = 88.16 * x + 29791.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1408853909.897978
# [010]  dy_i = 88.09 * x + 29918.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1408670176.758097
# [011]  dy_i = 88.01 * x + 30042.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1408490503.893680
# [012]  dy_i = 87.94 * x + 30163.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1408315630.632795
# [013]  dy_i = 87.86 * x + 30282.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1408145854.823165
# [014]  dy_i = 87.79 * x + 30399.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407981218.263421
# [015]  dy_i = 87.72 * x + 30515.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407821646.523703
# [016]  dy_i = 87.65 * x + 30628.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407667017.740080
# [017]  dy_i = 87.58 * x + 30740.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407517192.894366
# [018]  dy_i = 87.51 * x + 30849.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407372028.574944
# [019]  dy_i = 87.44 * x + 30958.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407231382.221150
# [020]  dy_i = 87.37 * x + 31064.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1407095114.216295
# [021]  dy_i = 87.30 * x + 31169.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406963088.673080
# [022]  dy_i = 87.24 * x + 31272.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406835173.679992
# [023]  dy_i = 87.17 * x + 31373.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406711241.327275
# [024]  dy_i = 87.11 * x + 31473.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406591167.644189
# [025]  dy_i = 87.05 * x + 31572.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406474832.501911
# [026]  dy_i = 86.99 * x + 31668.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406362119.504462
# [027]  dy_i = 86.93 * x + 31764.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406252915.876842
# [028]  dy_i = 86.87 * x + 31857.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406147112.354088
# [029]  dy_i = 86.81 * x + 31950.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1406044603.072727
# [030]  dy_i = 86.75 * x + 32040.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405945285.465183
# [031]  dy_i = 86.70 * x + 32130.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405849060.157275
# [032]  dy_i = 86.64 * x + 32218.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405755830.868850
# [033]  dy_i = 86.59 * x + 32305.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405665504.317464
# [034]  dy_i = 86.53 * x + 32390.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405577990.125060
# [035]  dy_i = 86.48 * x + 32474.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405493200.727542
# [036]  dy_i = 86.43 * x + 32556.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405411051.287161
# [037]  dy_i = 86.38 * x + 32638.27     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405331459.607630
# [038]  dy_i = 86.32 * x + 32718.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405254346.051880
# [039]  dy_i = 86.27 * x + 32797.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405179633.462381
# [040]  dy_i = 86.23 * x + 32874.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405107247.083937
# [041]  dy_i = 86.18 * x + 32951.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1405037114.488891
# [042]  dy_i = 86.13 * x + 33026.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404969165.504653
# [043]  dy_i = 86.08 * x + 33100.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404903332.143490
# [044]  dy_i = 86.04 * x + 33172.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404839548.534498
# [045]  dy_i = 85.99 * x + 33244.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404777750.857695
# [046]  dy_i = 85.95 * x + 33315.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404717877.280163
# [047]  dy_i = 85.90 * x + 33384.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404659867.894180
# [048]  dy_i = 85.86 * x + 33452.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404603664.657279
# [049]  dy_i = 85.82 * x + 33520.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404549211.334174
# [050]  dy_i = 85.78 * x + 33586.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404496453.440488
# [051]  dy_i = 85.73 * x + 33651.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404445338.188241
# [052]  dy_i = 85.69 * x + 33715.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404395814.433032
# [053]  dy_i = 85.65 * x + 33778.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404347832.622864
# [054]  dy_i = 85.61 * x + 33841.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404301344.748564
# [055]  dy_i = 85.58 * x + 33902.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404256304.295748
# [056]  dy_i = 85.54 * x + 33962.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404212666.198277
# [057]  dy_i = 85.50 * x + 34021.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404170386.793169
# [058]  dy_i = 85.46 * x + 34080.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404129423.776909
# [059]  dy_i = 85.43 * x + 34137.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404089736.163121
# [060]  dy_i = 85.39 * x + 34194.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404051284.241557
# [061]  dy_i = 85.36 * x + 34249.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1404014029.538368
# [062]  dy_i = 85.32 * x + 34304.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403977934.777608
# [063]  dy_i = 85.29 * x + 34358.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403942963.843930
# [064]  dy_i = 85.25 * x + 34411.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403909081.746459
# [065]  dy_i = 85.22 * x + 34463.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403876254.583775
# [066]  dy_i = 85.19 * x + 34515.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403844449.509995
# [067]  dy_i = 85.16 * x + 34565.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403813634.701909
# [068]  dy_i = 85.12 * x + 34615.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403783779.327136
# [069]  dy_i = 85.09 * x + 34664.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403754853.513275
# [070]  dy_i = 85.06 * x + 34712.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403726828.318017
# [071]  dy_i = 85.03 * x + 34760.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403699675.700185
# [072]  dy_i = 85.00 * x + 34807.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403673368.491677
# [073]  dy_i = 84.97 * x + 34853.09     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403647880.370283
# [074]  dy_i = 84.95 * x + 34898.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403623185.833345
# [075]  dy_i = 84.92 * x + 34942.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403599260.172246
# [076]  dy_i = 84.89 * x + 34986.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403576079.447678
# [077]  dy_i = 84.86 * x + 35030.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403553620.465699
# [078]  dy_i = 84.84 * x + 35072.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403531860.754520
# [079]  dy_i = 84.81 * x + 35114.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403510778.542020
# [080]  dy_i = 84.78 * x + 35155.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403490352.733964
# [081]  dy_i = 84.76 * x + 35196.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403470562.892896
# [082]  dy_i = 84.73 * x + 35236.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403451389.217690
# [083]  dy_i = 84.71 * x + 35275.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403432812.523736
# [084]  dy_i = 84.68 * x + 35314.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403414814.223746
# [085]  dy_i = 84.66 * x + 35352.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403397376.309157
# [086]  dy_i = 84.64 * x + 35389.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403380481.332111
# [087]  dy_i = 84.61 * x + 35426.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403364112.387994
# [088]  dy_i = 84.59 * x + 35462.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403348253.098529
# [089]  dy_i = 84.57 * x + 35498.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403332887.595383
# [090]  dy_i = 84.54 * x + 35533.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403318000.504289
# [091]  dy_i = 84.52 * x + 35568.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403303576.929666
# [092]  dy_i = 84.50 * x + 35602.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403289602.439716
# [093]  dy_i = 84.48 * x + 35635.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403276063.051978
# [094]  dy_i = 84.46 * x + 35669.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403262945.219345
# [095]  dy_i = 84.44 * x + 35701.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403250235.816502
# [096]  dy_i = 84.42 * x + 35733.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403237922.126799
# [097]  dy_i = 84.40 * x + 35764.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403225991.829525
# [098]  dy_i = 84.38 * x + 35795.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403214432.987578
# [099]  dy_i = 84.36 * x + 35826.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403203234.035525
# [100]  dy_i = 84.34 * x + 35856.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403192383.768028
# [101]  dy_i = 84.32 * x + 35886.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403181871.328632
# [102]  dy_i = 84.30 * x + 35915.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403171686.198902
# [103]  dy_i = 84.28 * x + 35943.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403161818.187901
# [104]  dy_i = 84.27 * x + 35972.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403152257.421989
# [105]  dy_i = 84.25 * x + 35999.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403142994.334950
# [106]  dy_i = 84.23 * x + 36027.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403134019.658413
# [107]  dy_i = 84.21 * x + 36053.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403125324.412584
# [108]  dy_i = 84.20 * x + 36080.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403116899.897258
# [109]  dy_i = 84.18 * x + 36106.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403108737.683116
# [110]  dy_i = 84.17 * x + 36132.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403100829.603290
# [111]  dy_i = 84.15 * x + 36157.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403093167.745190
# [112]  dy_i = 84.13 * x + 36182.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403085744.442587
# [113]  dy_i = 84.12 * x + 36206.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403078552.267948
# [114]  dy_i = 84.10 * x + 36230.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403071584.024994
# [115]  dy_i = 84.09 * x + 36254.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403064832.741510
# [116]  dy_i = 84.07 * x + 36277.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403058291.662363
# [117]  dy_i = 84.06 * x + 36300.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403051954.242742
# [118]  dy_i = 84.04 * x + 36323.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403045814.141614
# [119]  dy_i = 84.03 * x + 36345.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403039865.215377
# [120]  dy_i = 84.02 * x + 36367.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403034101.511713
# [121]  dy_i = 84.00 * x + 36388.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403028517.263629
# [122]  dy_i = 83.99 * x + 36410.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403023106.883694
# [123]  dy_i = 83.98 * x + 36430.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403017864.958442
# [124]  dy_i = 83.96 * x + 36451.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403012786.242960
# [125]  dy_i = 83.95 * x + 36471.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403007865.655635
# [126]  dy_i = 83.94 * x + 36491.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1403003098.273073
# [127]  dy_i = 83.93 * x + 36511.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402998479.325175
# [128]  dy_i = 83.91 * x + 36530.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402994004.190357
# [129]  dy_i = 83.90 * x + 36549.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402989668.390933
# [130]  dy_i = 83.89 * x + 36568.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402985467.588631
# [131]  dy_i = 83.88 * x + 36586.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402981397.580253
# [132]  dy_i = 83.87 * x + 36604.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402977454.293470
# [133]  dy_i = 83.86 * x + 36622.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402973633.782746
# [134]  dy_i = 83.84 * x + 36640.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402969932.225391
# [135]  dy_i = 83.83 * x + 36657.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402966345.917739
# [136]  dy_i = 83.82 * x + 36674.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402962871.271434
# [137]  dy_i = 83.81 * x + 36691.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402959504.809851
# [138]  dy_i = 83.80 * x + 36707.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402956243.164608
# [139]  dy_i = 83.79 * x + 36723.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402953083.072198
# [140]  dy_i = 83.78 * x + 36739.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402950021.370729
# [141]  dy_i = 83.77 * x + 36755.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402947054.996752
# [142]  dy_i = 83.76 * x + 36770.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402944180.982202
# [143]  dy_i = 83.75 * x + 36786.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402941396.451425
# [144]  dy_i = 83.74 * x + 36800.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402938698.618302
# [145]  dy_i = 83.73 * x + 36815.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402936084.783463
# [146]  dy_i = 83.72 * x + 36830.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402933552.331581
# [147]  dy_i = 83.71 * x + 36844.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402931098.728761
# [148]  dy_i = 83.71 * x + 36858.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402928721.520000
# [149]  dy_i = 83.70 * x + 36872.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402926418.326734
# [150]  dy_i = 83.69 * x + 36886.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402924186.844457
# [151]  dy_i = 83.68 * x + 36899.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402922024.840413
# [152]  dy_i = 83.67 * x + 36912.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402919930.151366
# [153]  dy_i = 83.66 * x + 36925.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402917900.681431
# [154]  dy_i = 83.66 * x + 36938.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402915934.399983
# [155]  dy_i = 83.65 * x + 36950.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402914029.339617
# [156]  dy_i = 83.64 * x + 36963.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402912183.594188
# [157]  dy_i = 83.63 * x + 36975.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402910395.316897
# [158]  dy_i = 83.62 * x + 36987.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402908662.718447
# [159]  dy_i = 83.62 * x + 36999.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402906984.065253
# [160]  dy_i = 83.61 * x + 37010.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402905357.677701
# [161]  dy_i = 83.60 * x + 37022.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402903781.928480
# [162]  dy_i = 83.60 * x + 37033.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402902255.240939
# [163]  dy_i = 83.59 * x + 37044.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402900776.087523
# [164]  dy_i = 83.58 * x + 37055.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402899342.988232
# [165]  dy_i = 83.57 * x + 37066.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402897954.509150
# [166]  dy_i = 83.57 * x + 37077.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402896609.261008
# [167]  dy_i = 83.56 * x + 37087.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402895305.897789
# [168]  dy_i = 83.55 * x + 37097.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402894043.115388
# [169]  dy_i = 83.55 * x + 37107.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402892819.650301
# [170]  dy_i = 83.54 * x + 37117.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402891634.278366
# [171]  dy_i = 83.54 * x + 37127.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402890485.813534
# [172]  dy_i = 83.53 * x + 37137.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402889373.106687
# [173]  dy_i = 83.52 * x + 37146.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402888295.044482
# [174]  dy_i = 83.52 * x + 37155.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402887250.548244
# [175]  dy_i = 83.51 * x + 37165.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402886238.572879
# [176]  dy_i = 83.51 * x + 37174.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402885258.105835
# [177]  dy_i = 83.50 * x + 37182.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402884308.166086
# [178]  dy_i = 83.50 * x + 37191.65     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402883387.803152
# [179]  dy_i = 83.49 * x + 37200.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402882496.096143
# [180]  dy_i = 83.48 * x + 37208.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402881632.152845
# [181]  dy_i = 83.48 * x + 37217.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402880795.108821
# [182]  dy_i = 83.47 * x + 37225.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402879984.126551
# [183]  dy_i = 83.47 * x + 37233.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402879198.394588
# [184]  dy_i = 83.46 * x + 37241.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402878437.126754
# [185]  dy_i = 83.46 * x + 37249.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402877699.561347
# [186]  dy_i = 83.45 * x + 37256.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402876984.960380
# [187]  dy_i = 83.45 * x + 37264.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402876292.608844
# [188]  dy_i = 83.44 * x + 37271.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402875621.813995
# [189]  dy_i = 83.44 * x + 37279.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402874971.904653
# [190]  dy_i = 83.44 * x + 37286.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402874342.230539
# [191]  dy_i = 83.43 * x + 37293.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402873732.161620
# [192]  dy_i = 83.43 * x + 37300.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402873141.087480
# [193]  dy_i = 83.42 * x + 37307.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402872568.416707
# [194]  dy_i = 83.42 * x + 37314.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402872013.576303
# [195]  dy_i = 83.41 * x + 37321.00     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402871476.011112
# [196]  dy_i = 83.41 * x + 37327.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402870955.183261
# [197]  dy_i = 83.41 * x + 37334.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402870450.571628
# [198]  dy_i = 83.40 * x + 37340.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402869961.671311
# [199]  dy_i = 83.40 * x + 37346.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402869487.993131
# [200]  dy_i = 83.39 * x + 37352.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402869029.063141
# [201]  dy_i = 83.39 * x + 37358.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402868584.422149
# [202]  dy_i = 83.39 * x + 37364.94     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402868153.625260
# [203]  dy_i = 83.38 * x + 37370.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402867736.241431
# [204]  dy_i = 83.38 * x + 37376.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402867331.853041
# [205]  dy_i = 83.37 * x + 37382.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402866940.055471
# [206]  dy_i = 83.37 * x + 37387.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402866560.456699
# [207]  dy_i = 83.37 * x + 37393.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402866192.676911
# [208]  dy_i = 83.36 * x + 37398.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402865836.348116
# [209]  dy_i = 83.36 * x + 37404.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402865491.113784
# [210]  dy_i = 83.36 * x + 37409.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402865156.628483
# [211]  dy_i = 83.35 * x + 37414.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402864832.557536
# [212]  dy_i = 83.35 * x + 37419.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402864518.576688
# [213]  dy_i = 83.35 * x + 37424.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402864214.371778
# [214]  dy_i = 83.34 * x + 37429.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402863919.638431
# [215]  dy_i = 83.34 * x + 37434.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402863634.081742
# [216]  dy_i = 83.34 * x + 37439.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402863357.415992
# [217]  dy_i = 83.34 * x + 37444.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402863089.364358
# [218]  dy_i = 83.33 * x + 37448.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402862829.658637
# [219]  dy_i = 83.33 * x + 37453.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402862578.038974
# [220]  dy_i = 83.33 * x + 37457.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402862334.253604
# [221]  dy_i = 83.32 * x + 37462.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402862098.058606
# [222]  dy_i = 83.32 * x + 37466.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402861869.217648
# [223]  dy_i = 83.32 * x + 37471.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402861647.501759
# [224]  dy_i = 83.32 * x + 37475.24     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402861432.689096
# [225]  dy_i = 83.31 * x + 37479.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402861224.564726
# [226]  dy_i = 83.31 * x + 37483.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402861022.920404
# [227]  dy_i = 83.31 * x + 37487.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402860827.554372
# [228]  dy_i = 83.31 * x + 37491.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402860638.271151
# [229]  dy_i = 83.30 * x + 37495.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402860454.881351
# [230]  dy_i = 83.30 * x + 37499.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402860277.201477
# [231]  dy_i = 83.30 * x + 37503.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402860105.053749
# [232]  dy_i = 83.30 * x + 37506.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859938.265919
# [233]  dy_i = 83.29 * x + 37510.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859776.671106
# [234]  dy_i = 83.29 * x + 37514.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859620.107622
# [235]  dy_i = 83.29 * x + 37517.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859468.418815
# [236]  dy_i = 83.29 * x + 37521.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859321.452909
# [237]  dy_i = 83.28 * x + 37524.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859179.062854
# [238]  dy_i = 83.28 * x + 37527.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402859041.106180
# [239]  dy_i = 83.28 * x + 37531.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858907.444850
# [240]  dy_i = 83.28 * x + 37534.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858777.945129
# [241]  dy_i = 83.28 * x + 37537.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858652.477440
# [242]  dy_i = 83.27 * x + 37540.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858530.916246
# [243]  dy_i = 83.27 * x + 37544.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858413.139917
# [244]  dy_i = 83.27 * x + 37547.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858299.030608
# [245]  dy_i = 83.27 * x + 37550.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858188.474145
# [246]  dy_i = 83.27 * x + 37553.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402858081.359908
# [247]  dy_i = 83.26 * x + 37556.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857977.580723
# [248]  dy_i = 83.26 * x + 37558.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857877.032751
# [249]  dy_i = 83.26 * x + 37561.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857779.615387
# [250]  dy_i = 83.26 * x + 37564.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857685.231157
# [251]  dy_i = 83.26 * x + 37567.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857593.785624
# [252]  dy_i = 83.26 * x + 37570.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857505.187290
# [253]  dy_i = 83.25 * x + 37572.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857419.347507
# [254]  dy_i = 83.25 * x + 37575.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857336.180384
# [255]  dy_i = 83.25 * x + 37577.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857255.602709
# [256]  dy_i = 83.25 * x + 37580.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857177.533856
# [257]  dy_i = 83.25 * x + 37583.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1402857101.895714
# [000]  dy_i = 93.50 * x + 36671.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2155645246.715658
# [001]  dy_i = 94.95 * x + 35322.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2142624874.815119
# [002]  dy_i = 95.83 * x + 34027.02     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2133794556.846570
# [003]  dy_i = 96.63 * x + 32808.30     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2126115303.380701
# [004]  dy_i = 97.38 * x + 31663.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2119347852.291434
# [005]  dy_i = 98.08 * x + 30588.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2113379043.704254
# [006]  dy_i = 98.74 * x + 29578.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2108114356.996370
# [007]  dy_i = 99.36 * x + 28630.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2103470714.082968
# [008]  dy_i = 99.94 * x + 27740.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2099374853.288510
# [009]  dy_i = 100.48 * x + 26903.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2095762156.064775
# [010]  dy_i = 101.00 * x + 26118.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2092575626.566880
# [011]  dy_i = 101.48 * x + 25380.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2089764992.402809
# [012]  dy_i = 101.93 * x + 24687.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2087285911.506340
# [013]  dy_i = 102.36 * x + 24037.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2085099272.572750
# [014]  dy_i = 102.75 * x + 23425.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2083170578.017964
# [015]  dy_i = 103.13 * x + 22851.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2081469399.726241
# [016]  dy_i = 103.48 * x + 22312.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2079968898.999960
# [017]  dy_i = 103.81 * x + 21806.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2078645403.137989
# [018]  dy_i = 104.12 * x + 21331.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2077478031.962504
# [019]  dy_i = 104.41 * x + 20884.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2076448368.402150
# [020]  dy_i = 104.69 * x + 20465.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2075540167.934478
# [021]  dy_i = 104.95 * x + 20071.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2074739102.303685
# [022]  dy_i = 105.19 * x + 19701.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2074032533.470393
# [023]  dy_i = 105.41 * x + 19354.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2073409314.227190
# [024]  dy_i = 105.63 * x + 19028.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2072859612.334326
# [025]  dy_i = 105.83 * x + 18721.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2072374755.401051
# [026]  dy_i = 106.01 * x + 18433.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2071947094.065338
# [027]  dy_i = 106.19 * x + 18163.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2071569881.313471
# [028]  dy_i = 106.36 * x + 17909.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2071237166.035541
# [029]  dy_i = 106.51 * x + 17671.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2070943699.137563
# [030]  dy_i = 106.66 * x + 17447.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2070684850.728964
# [031]  dy_i = 106.80 * x + 17237.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2070456537.078956
# [032]  dy_i = 106.93 * x + 17039.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2070255156.189413
# [033]  dy_i = 107.05 * x + 16854.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2070077530.967831
# [034]  dy_i = 107.16 * x + 16680.21     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069920859.103814
# [035]  dy_i = 107.27 * x + 16516.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069782668.858330
# [036]  dy_i = 107.37 * x + 16363.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069660780.068234
# [037]  dy_i = 107.46 * x + 16218.72     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069553269.750854
# [038]  dy_i = 107.55 * x + 16083.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069458441.765983
# [039]  dy_i = 107.63 * x + 15955.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069374800.056667
# [040]  dy_i = 107.71 * x + 15836.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069301025.046613
# [041]  dy_i = 107.78 * x + 15724.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069235952.821845
# [042]  dy_i = 107.85 * x + 15618.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069178556.768181
# [043]  dy_i = 107.92 * x + 15519.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069127931.374813
# [044]  dy_i = 107.98 * x + 15426.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069083277.948486
# [045]  dy_i = 108.04 * x + 15339.45     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069043892.012890
# [046]  dy_i = 108.09 * x + 15257.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2069009152.194464
# [047]  dy_i = 108.14 * x + 15180.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068978510.419270
# [048]  dy_i = 108.19 * x + 15108.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068951483.266291
# [049]  dy_i = 108.23 * x + 15040.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068927644.340724
# [050]  dy_i = 108.27 * x + 14976.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068906617.546941
# [051]  dy_i = 108.31 * x + 14916.39     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068888071.155011
# [052]  dy_i = 108.35 * x + 14860.11     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068871712.567144
# [053]  dy_i = 108.38 * x + 14807.25     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068857283.701520
# [054]  dy_i = 108.42 * x + 14757.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068844556.920644
# [055]  dy_i = 108.45 * x + 14710.99     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068833331.440023
# [056]  dy_i = 108.47 * x + 14667.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068823430.160477
# [057]  dy_i = 108.50 * x + 14626.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068814696.874128
# [058]  dy_i = 108.53 * x + 14587.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068806993.799988
# [059]  dy_i = 108.55 * x + 14551.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068800199.410241
# [060]  dy_i = 108.57 * x + 14517.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068794206.512964
# [061]  dy_i = 108.59 * x + 14485.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068788920.561011
# [062]  dy_i = 108.61 * x + 14455.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068784258.160377
# [063]  dy_i = 108.63 * x + 14426.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068780145.754540
# [064]  dy_i = 108.65 * x + 14400.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068776518.463987
# [065]  dy_i = 108.66 * x + 14375.47     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068773319.062646
# [066]  dy_i = 108.68 * x + 14352.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068770497.075051
# [067]  dy_i = 108.69 * x + 14330.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068768007.980017
# [068]  dy_i = 108.71 * x + 14309.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068765812.508254
# [069]  dy_i = 108.72 * x + 14290.16     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068763876.022824
# [070]  dy_i = 108.73 * x + 14271.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068762167.972698
# [071]  dy_i = 108.74 * x + 14254.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068760661.410766
# [072]  dy_i = 108.75 * x + 14238.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068759332.568702
# [073]  dy_i = 108.76 * x + 14223.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068758160.481982
# [074]  dy_i = 108.77 * x + 14209.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068757126.659142
# [075]  dy_i = 108.78 * x + 14196.35     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068756214.790039
# [076]  dy_i = 108.79 * x + 14183.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068755410.488540
# [077]  dy_i = 108.80 * x + 14172.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068754701.065553
# [078]  dy_i = 108.80 * x + 14161.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068754075.328844
# [079]  dy_i = 108.81 * x + 14150.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068753523.406455
# [080]  dy_i = 108.82 * x + 14141.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068753036.590964
# [081]  dy_i = 108.82 * x + 14131.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068752607.202109
# [082]  dy_i = 108.83 * x + 14123.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068752228.465623
# [083]  dy_i = 108.83 * x + 14115.37     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068751894.406357
# [084]  dy_i = 108.84 * x + 14107.82     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068751599.754012
# [085]  dy_i = 108.84 * x + 14100.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068751339.859997
# [086]  dy_i = 108.85 * x + 14094.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068751110.624084
# [087]  dy_i = 108.85 * x + 14087.81     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750908.429725
# [088]  dy_i = 108.86 * x + 14081.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750730.086995
# [089]  dy_i = 108.86 * x + 14076.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750572.782262
# [090]  dy_i = 108.86 * x + 14071.23     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750434.033803
# [091]  dy_i = 108.87 * x + 14066.36     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750311.652648
# [092]  dy_i = 108.87 * x + 14061.79     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750203.708048
# [093]  dy_i = 108.87 * x + 14057.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750108.497010
# [094]  dy_i = 108.88 * x + 14053.46     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068750024.517434
# [095]  dy_i = 108.88 * x + 14049.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749950.444412
# [096]  dy_i = 108.88 * x + 14046.12     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749885.109331
# [097]  dy_i = 108.88 * x + 14042.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749827.481429
# [098]  dy_i = 108.88 * x + 14039.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749776.651537
# [099]  dy_i = 108.89 * x + 14036.70     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749731.817735
# [100]  dy_i = 108.89 * x + 14033.93     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749692.272701
# [101]  dy_i = 108.89 * x + 14031.33     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749657.392553
# [102]  dy_i = 108.89 * x + 14028.89     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749626.627002
# [103]  dy_i = 108.89 * x + 14026.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749599.490674
# [104]  dy_i = 108.89 * x + 14024.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749575.555452
# [105]  dy_i = 108.90 * x + 14022.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749554.443721
# [106]  dy_i = 108.90 * x + 14020.52     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749535.822412
# [107]  dy_i = 108.90 * x + 14018.74     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749519.397744
# [108]  dy_i = 108.90 * x + 14017.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749504.910594
# [109]  dy_i = 108.90 * x + 14015.49     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749492.132404
# [110]  dy_i = 108.90 * x + 14014.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749480.861578
# [111]  dy_i = 108.90 * x + 14012.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749470.920303
# [112]  dy_i = 108.90 * x + 14011.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749462.151739
# [113]  dy_i = 108.90 * x + 14010.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749454.417548
# [114]  dy_i = 108.90 * x + 14008.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749447.595713
# [115]  dy_i = 108.91 * x + 14007.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749441.578608
# [116]  dy_i = 108.91 * x + 14006.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749436.271304
# [117]  dy_i = 108.91 * x + 14005.91     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749431.590069
# [118]  dy_i = 108.91 * x + 14005.01     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749427.461052
# [119]  dy_i = 108.91 * x + 14004.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749423.819109
# [120]  dy_i = 108.91 * x + 14003.38     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749420.606784
# [121]  dy_i = 108.91 * x + 14002.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749417.773397
# [122]  dy_i = 108.91 * x + 14001.95     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749415.274247
# [123]  dy_i = 108.91 * x + 14001.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749413.069907
# [124]  dy_i = 108.91 * x + 14000.68     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749411.125599
# [125]  dy_i = 108.91 * x + 14000.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749409.410649
# [126]  dy_i = 108.91 * x + 13999.56     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749407.898002
# [127]  dy_i = 108.91 * x + 13999.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749406.563792
# [128]  dy_i = 108.91 * x + 13998.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2068749405.386971
# [000]  dy_i = 89.39 * x + 26939.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1322521874.653058
# [001]  dy_i = 89.76 * x + 29123.20     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1315326387.685238
# [002]  dy_i = 87.05 * x + 32573.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1295241005.095342
# [003]  dy_i = 85.26 * x + 35260.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1283430739.625644
# [004]  dy_i = 83.62 * x + 37618.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1274280170.817738
# [005]  dy_i = 82.23 * x + 39635.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1267591524.936864
# [006]  dy_i = 81.04 * x + 41370.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1262644049.073333
# [007]  dy_i = 80.01 * x + 42860.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1258993394.469775
# [008]  dy_i = 79.13 * x + 44140.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1256298295.147837
# [009]  dy_i = 78.37 * x + 45240.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1254308839.262475
# [010]  dy_i = 77.72 * x + 46185.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1252840241.119687
# [011]  dy_i = 77.16 * x + 46997.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1251756140.069017
# [012]  dy_i = 76.68 * x + 47695.19     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1250955869.326624
# [013]  dy_i = 76.27 * x + 48294.58     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1250365118.912019
# [014]  dy_i = 75.91 * x + 48809.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249929033.913745
# [015]  dy_i = 75.61 * x + 49252.03     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249607121.106628
# [016]  dy_i = 75.34 * x + 49632.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249369488.865304
# [017]  dy_i = 75.12 * x + 49958.80     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249194071.544680
# [018]  dy_i = 74.93 * x + 50239.43     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1249064580.545457
# [019]  dy_i = 74.76 * x + 50480.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248968991.815564
# [020]  dy_i = 74.62 * x + 50687.69     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248898429.341435
# [021]  dy_i = 74.49 * x + 50865.67     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248846340.954440
# [022]  dy_i = 74.39 * x + 51018.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248807889.920893
# [023]  dy_i = 74.30 * x + 51149.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248779505.820980
# [024]  dy_i = 74.22 * x + 51262.86     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248758553.012861
# [025]  dy_i = 74.15 * x + 51359.84     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248743085.896785
# [026]  dy_i = 74.10 * x + 51443.17     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248731668.253940
# [027]  dy_i = 74.05 * x + 51514.76     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248723239.884521
# [028]  dy_i = 74.00 * x + 51576.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248717018.161523
# [029]  dy_i = 73.97 * x + 51629.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248712425.358913
# [030]  dy_i = 73.94 * x + 51674.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248709035.006142
# [031]  dy_i = 73.91 * x + 51713.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248706532.287673
# [032]  dy_i = 73.89 * x + 51747.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248704684.810388
# [033]  dy_i = 73.87 * x + 51775.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248703321.024424
# [034]  dy_i = 73.85 * x + 51800.61     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248702314.293694
# [035]  dy_i = 73.84 * x + 51821.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248701571.136932
# [036]  dy_i = 73.82 * x + 51840.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248701022.547366
# [037]  dy_i = 73.81 * x + 51855.83     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248700617.585012
# [038]  dy_i = 73.80 * x + 51869.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248700318.646574
# [039]  dy_i = 73.79 * x + 51880.90     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248700097.973741
# [040]  dy_i = 73.79 * x + 51890.85     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699935.075656
# [041]  dy_i = 73.78 * x + 51899.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699814.826209
# [042]  dy_i = 73.78 * x + 51906.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699726.059484
# [043]  dy_i = 73.77 * x + 51913.06     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699660.532933
# [044]  dy_i = 73.77 * x + 51918.48     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699612.162006
# [045]  dy_i = 73.77 * x + 51923.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699576.455157
# [046]  dy_i = 73.76 * x + 51927.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699550.096782
# [047]  dy_i = 73.76 * x + 51930.59     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699530.639340
# [048]  dy_i = 73.76 * x + 51933.54     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699516.276086
# [049]  dy_i = 73.76 * x + 51936.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699505.673301
# [050]  dy_i = 73.76 * x + 51938.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699497.846450
# [051]  dy_i = 73.75 * x + 51940.14     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699492.068760
# [052]  dy_i = 73.75 * x + 51941.75     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699487.803738
# [053]  dy_i = 73.75 * x + 51943.13     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699484.655349
# [054]  dy_i = 73.75 * x + 51944.32     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699482.331245
# [055]  dy_i = 73.75 * x + 51945.34     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699480.615620
# [056]  dy_i = 73.75 * x + 51946.22     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699479.349165
# [057]  dy_i = 73.75 * x + 51946.98     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699478.414283
# [058]  dy_i = 73.75 * x + 51947.62     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699477.724164
# [059]  dy_i = 73.75 * x + 51948.18     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699477.214726
# [060]  dy_i = 73.75 * x + 51948.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699476.838665
# [061]  dy_i = 73.75 * x + 51949.07     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699476.561061
# [062]  dy_i = 73.75 * x + 51949.42     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699476.356138
# [063]  dy_i = 73.75 * x + 51949.73     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1248699476.204865
# [000]  dy_i = 85.31 * x + 29869.08     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1484290802.764258
# [001]  dy_i = 105.13 * x + -1223.53     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1625236601.482903
# [002]  dy_i = 123.99 * x + -24789.04     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1833324338.918327
# [003]  dy_i = 128.44 * x + -20602.60     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1848221019.507128
# [004]  dy_i = 107.69 * x + 23322.63     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1785528978.303978
# [005]  dy_i = 62.50 * x + 98086.31     previously calculated: y_i = 87.69 * x + 34754.08    loss: 2378048401.806617
# [006]  dy_i = 10.84 * x + 168830.10     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3727651984.567964
# [007]  dy_i = -15.25 * x + 184788.28     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4327826817.025693
# [008]  dy_i = 15.83 * x + 105652.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3703884987.840303
# [009]  dy_i = 113.37 * x + -65129.26     previously calculated: y_i = 87.69 * x + 34754.08    loss: 5683427637.536418
# [010]  dy_i = 245.92 * x + -259285.71     previously calculated: y_i = 87.69 * x + 34754.08    loss: 13382598319.331028
# [011]  dy_i = 341.16 * x + -355918.51     previously calculated: y_i = 87.69 * x + 34754.08    loss: 19888028924.989384
# [012]  dy_i = 313.65 * x + -236392.41     previously calculated: y_i = 87.69 * x + 34754.08    loss: 17053593523.670628
# [013]  dy_i = 116.57 * x + 132930.40     previously calculated: y_i = 87.69 * x + 34754.08    loss: 20808906676.187740
# [014]  dy_i = -205.50 * x + 632051.92     previously calculated: y_i = 87.69 * x + 34754.08    loss: 59616278217.644165
# [015]  dy_i = -498.17 * x + 987511.44     previously calculated: y_i = 87.69 * x + 34754.08    loss: 111505055965.045914
# [016]  dy_i = -544.58 * x + 878105.64     previously calculated: y_i = 87.69 * x + 34754.08    loss: 110612321429.528046
# [017]  dy_i = -180.96 * x + 130038.29     previously calculated: y_i = 87.69 * x + 34754.08    loss: 99569367697.610367
# [018]  dy_i = 562.44 * x + -1084703.55     previously calculated: y_i = 87.69 * x + 34754.08    loss: 269262744833.258942
# [019]  dy_i = 1378.19 * x + -2181335.77     previously calculated: y_i = 87.69 * x + 34754.08    loss: 617134434901.693115
# [020]  dy_i = 1744.48 * x + -2343031.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 741352305288.310181
# [021]  dy_i = 1168.88 * x + -957939.66     previously calculated: y_i = 87.69 * x + 34754.08    loss: 584621706905.269043
# [022]  dy_i = -457.54 * x + 1850593.88     previously calculated: y_i = 87.69 * x + 34754.08    loss: 1190619444731.664062
# [023]  dy_i = -2579.96 * x + 4915017.78     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3233060321173.323242
# [024]  dy_i = -4005.58 * x + 6266615.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 4757071484432.834961
# [025]  dy_i = -3381.57 * x + 4059247.57     previously calculated: y_i = 87.69 * x + 34754.08    loss: 3918440267831.444824
# [026]  dy_i = -38.97 * x + -2096398.05     previously calculated: y_i = 87.69 * x + 34754.08    loss: 5334319975568.642578
# [027]  dy_i = 5181.35 * x + -10085019.87     previously calculated: y_i = 87.69 * x + 34754.08    loss: 15938516807276.828125
# [028]  dy_i = 9697.84 * x + -15398828.50     previously calculated: y_i = 87.69 * x + 34754.08    loss: 28759311064873.039062
# [029]  dy_i = 10029.96 * x + -12953758.15     previously calculated: y_i = 87.69 * x + 34754.08    loss: 27372216899664.250000
# [030]  dy_i = 3708.39 * x + -274416.97     previously calculated: y_i = 87.69 * x + 34754.08    loss: 26126792236501.804688
# [031]  dy_i = -8486.53 * x + 19407733.96     previously calculated: y_i = 87.69 * x + 34754.08    loss: 74214363227828.312500
